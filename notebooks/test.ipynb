# %%
import json
from pathlib import Path

import pandas as pd
import numpy as np
import pretty_midi
from mingus.containers import Note
from mingus.containers import Bar
from mingus.containers import Track
from mingus.containers import Composition
from mingus.midi import midi_file_out
import numpy as np
import pretty_midi

import sys
parentDir = Path.cwd().parent
sys.path.insert(0, str(parentDir))

# %%
from utils import run_realtime_music

# %%
# Run it:
await run_realtime_music(max_seconds=30)
# Out:
# Connecting to stream2.mindfulmakers.xyz
# Logging incoming EEG messages to eeg_stream_live.jsonl
#
# ⏹️  Stopped streaming after 30 seconds.
#
# Saved MIDI as eeg_lofi_live.mid
